# %% [markdown]
# <a href="https://colab.research.google.com/github/manasathirumalareddy/python_fundamentals/blob/main/pandas_7_sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people = {
    'first': ['corey','jane','john','adam'],
    'last': ['schafer','doe','doe','doe'],
    'email': ['coreyschafer@gmail.com','janedoe@email.com','johndoe@emailcom','a@email.com']

}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom
# 3   adam      doe             a@email.com

# %%
df.sort_values(by='last')
# Out:
#    first     last                   email
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom
# 3   adam      doe             a@email.com
# 0  corey  schafer  coreyschafer@gmail.com

# %%
df.sort_values(by='last',ascending=False)
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom
# 3   adam      doe             a@email.com

# %%
df.sort_values(by=['last','first'],ascending=False)
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 2   john      doe        johndoe@emailcom
# 1   jane      doe       janedoe@email.com
# 3   adam      doe             a@email.com

# %%
df.sort_values(by=['last','first'],ascending=[False,True])
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 3   adam      doe             a@email.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom

# %%
df.sort_index()
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom
# 3   adam      doe             a@email.com

# %%
df['last'].sort_values()
# Out:
# 1        doe
# 2        doe
# 3        doe
# 0    schafer
# Name: last, dtype: object
