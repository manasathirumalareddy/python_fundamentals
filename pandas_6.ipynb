# %% [markdown]
# <a href="https://colab.research.google.com/github/manasathirumalareddy/python_fundamentals/blob/main/pandas_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# add/remove rows and columns from data frame

# %%
people = {
    'first': ['corey','jane','john'],
    'last': ['schafer','doe','doe'],
    'email': ['coreyschafer@gmail.com','janedoe@email.com','johndoe@emailcom']

}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gmail.com
# 1   jane      doe       janedoe@email.com
# 2   john      doe        johndoe@emailcom

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    corey schafer
# 1         jane doe
# 2         john doe
# dtype: object

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                   email      full_name
# 0  corey  schafer  coreyschafer@gmail.com  corey schafer
# 1   jane      doe       janedoe@email.com       jane doe
# 2   john      doe        johndoe@emailcom       john doe

# %%
df.drop(columns=['first','last'],inplace=True)

# %%
df
# Out:
#                     email      full_name
# 0  coreyschafer@gmail.com  corey schafer
# 1       janedoe@email.com       jane doe
# 2        johndoe@emailcom       john doe

# %%
df['full_name'].str.split(' ')
# Out:
# 0    [corey, schafer]
# 1         [jane, doe]
# 2         [john, doe]
# 3                 NaN
# 4                 NaN
# Name: full_name, dtype: object

# %%
df['full_name'].str.split(' ',expand=True)
# Out:
#        0        1
# 0  corey  schafer
# 1   jane      doe
# 2   john      doe

# %%
df[['first','last']] = df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  corey schafer  corey  schafer
# 1       janedoe@email.com       jane doe   jane      doe
# 2        johndoe@emailcom       john doe   john      doe

# %%
df.append({'first' : 'tony'},ignore_index=True)
# Out:
# <ipython-input-14-8f4278a46048>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append({'first' : 'tony'},ignore_index=True)
#                     email      full_name  first     last
# 0  coreyschafer@gmail.com  corey schafer  corey  schafer
# 1       janedoe@email.com       jane doe   jane      doe
# 2        johndoe@emailcom       john doe   john      doe
# 3                     NaN            NaN   tony      NaN

# %%
people = {
    'first': ['manasa','reddy'],
    'last': ['vamsi','venna'],
    'email': ['manasa@gmaiil.com','vamsivenna@email.com']

}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#     first   last                 email
# 0  manasa  vamsi     manasa@gmaiil.com
# 1   reddy  venna  vamsivenna@email.com

# %%
df.append(df2,ignore_index=True)
# Out:
# <ipython-input-17-b5bdafa87b23>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df2,ignore_index=True)
#                     email      full_name   first     last
# 0  coreyschafer@gmail.com  corey schafer   corey  schafer
# 1       janedoe@email.com       jane doe    jane      doe
# 2        johndoe@emailcom       john doe    john      doe
# 3       manasa@gmaiil.com            NaN  manasa    vamsi
# 4    vamsivenna@email.com            NaN   reddy    venna

# %%
df = df.append(df2,ignore_index=True)
# Out:
# <ipython-input-18-89b8b502bfc4>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2,ignore_index=True)

# %%
df
# Out:
#                     email      full_name   first     last
# 0  coreyschafer@gmail.com  corey schafer   corey  schafer
# 1       janedoe@email.com       jane doe    jane      doe
# 2        johndoe@emailcom       john doe    john      doe
# 3       manasa@gmaiil.com            NaN  manasa    vamsi
# 4    vamsivenna@email.com            NaN   reddy    venna

# %%
df.drop(index=4)
# Out:
#                     email      full_name   first     last
# 0  coreyschafer@gmail.com  corey schafer   corey  schafer
# 1       janedoe@email.com       jane doe    jane      doe
# 2        johndoe@emailcom       john doe    john      doe
# 3       manasa@gmaiil.com            NaN  manasa    vamsi

# %%
df.drop(index=df[df['last'] == 'doe'].index)
# Out:
#                     email      full_name   first     last
# 0  coreyschafer@gmail.com  corey schafer   corey  schafer
# 3       manasa@gmaiil.com            NaN  manasa    vamsi
# 4    vamsivenna@email.com            NaN   reddy    venna

# %%
filt = df['last'] == 'doe'
df.drop(index=df[filt].index)
# Out:
#                     email      full_name   first     last
# 0  coreyschafer@gmail.com  corey schafer   corey  schafer
# 3       manasa@gmaiil.com            NaN  manasa    vamsi
# 4    vamsivenna@email.com            NaN   reddy    venna
